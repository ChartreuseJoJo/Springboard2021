# %%
CAPSTONE 2 PROJECT 

DESCRIPTION:

Predicting U.S. life expectancy at birth using education, income, unemployment, and poverty data.


PROCEDURE:

1. Obtain following datasets:  A. life table function from National Center for Health Statistics, B. Poverty Statistics, 
    C. Income datasets, D. Education Attainment dataset


DATA WRANGLING:

Five datasets used to create the following five dataframes:
    1.  df_mortality
    2.  df_poverty (contains income data)
    3.  df_education
    4.  df_unemployment
    5.  df_states (contains US States and FIPS codes)
    6.  df_county (contains US States and county FIPS codes).  all-geocodes-v2017.xlsx
    
Making Tidy Dat
    1. Check outliers and missing values.  Impute or drop missing values.
    2. Drop columns that are not needed

Merging DataFrames
    1. merg df_mortality, df_states, df_county to allow identify of county and state for entry
    2. merge df_employment and df_education to create df_emp_edu
        a.  merge df_emp_edu and df_poverty to create df_emp_edu_pov.
    3. merge df_mortalty and df_emp_edu_pov. this will be the primary dataframe used in exploratory
    data analysis
# Out:
#   File "<ipython-input-346-555c5a4c96a7>", line 1
#     CAPSTONE 2 PROJECT
#              ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Import life tables
#Tract ID consists is a concatenation of three numerical codes.  2-digit state FIPS code, 3-digit county
#FIPS code, and 6-digit census tract number.


df_mortality = pd.read_csv('/Users/marshallbanana/GitHub/Springboard2021/CAPSTONE 2 PROJECT FILES/Capstone 2 Project Data/US_A.csv')

# %%
df_mortality.info()

#zero non-null values in df_mortality
#e(0) is the life expectancy at birth.  this is the target value.
#STATE2KX, CNTY2KX columns with be important when joining all dataframes together
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65662 entries, 0 to 65661
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tract ID                  65662 non-null  int64
#  1   STATE2KX                  65662 non-null  int64
#  2   CNTY2KX                   65662 non-null  int64
#  3   TRACT2KX                  65662 non-null  int64
#  4   e(0)                      65662 non-null  float64
#  5   se(e(0))                  65662 non-null  float64
#  6   Abridged life table flag  65662 non-null  int64
#  7   STUSAB_x                  65662 non-null  object
#  8   STATE_NAME_x              65662 non-null  object
#  9   STATENS_x                 65662 non-null  int64
#  10  STUSAB_y                  65662 non-null  object
#  11  STATE_NAME_y              65662 non-null  object
#  12  STATENS_y                 65662 non-null  int64
# ...

# %%
df_mortality.head()
# Out:
#      Tract ID  STATE2KX  CNTY2KX  TRACT2KX  e(0)  se(e(0))  \
# 0  1001020100         1        1     20100  73.1    2.2348
# 1  1001020200         1        1     20200  76.9    3.3453
# 2  1001020400         1        1     20400  75.4    1.0216
# 3  1001020500         1        1     20500  79.4    1.1768
# 4  1001020600         1        1     20600  73.1    1.5519
#
#    Abridged life table flag STUSAB_x STATE_NAME_x  STATENS_x STUSAB_y  \
# 0                         3       AL      Alabama    1779775       AL
# 1                         3       AL      Alabama    1779775       AL
# 2                         3       AL      Alabama    1779775       AL
# 3                         1       AL      Alabama    1779775       AL
# 4                         3       AL      Alabama    1779775       AL
#
#   STATE_NAME_y  STATENS_y  State_x County Name_x  State_y County Name_y
# 0      Alabama    1779775  Alabama       Autauga  Alabama       Autauga
# ...

# %%
df_mortality.sample(5)
# Out:
#           Tract ID  STATE2KX  CNTY2KX  TRACT2KX  e(0)  se(e(0))  \
# 61732  49049002701        49       49      2701  80.1    1.8421
# 56021  47115050302        47      115     50302  77.2    1.2611
# 53594  42125771200        42      125    771200  77.5    1.3101
# 58190  48141000404        48      141       404  75.7    1.9606
# 15395  12095016200        12       95     16200  81.8    1.4247
#
#        Abridged life table flag STUSAB_x  STATE_NAME_x  STATENS_x STUSAB_y  \
# 61732                         3       UT          Utah    1455989       UT
# 56021                         3       TN     Tennessee    1325873       TN
# 53594                         3       PA  Pennsylvania    1779798       PA
# 58190                         2       TX         Texas    1779801       TX
# 15395                         3       FL       Florida     294478       FL
#
#        STATE_NAME_y  STATENS_y       State_x County Name_x       State_y  \
# ...

# %%
#import US State FIPS code data

df_state = pd.read_csv('/Users/marshallbanana/GitHub/Springboard2021/CAPSTONE 2 PROJECT FILES/Capstone 2 Project Data/StatesFIPSCodes.csv')
df_state.columns
# Out:
# Index(['STATE_FIPS', 'STUSAB', 'STATE_NAME', 'STATENS'], dtype='object')

# %%
# import US State and County FIPS code data 
df_county = pd.read_excel('/Users/marshallbanana/GitHub/Springboard2021/CAPSTONE 2 PROJECT FILES/Capstone 2 Project Data/US_FIPS_Codes.xls', header = 1)
df_county = df_county.rename(columns={"FIPS State": "STATE2KX"})
df_county = df_county.rename(columns={"FIPS County": "CNTY2KX"})
df_county.head(5)
df_county.sample(5)
# Out:
#              State County Name  STATE2KX  CNTY2KX
# 1564      Missouri     Pulaski        29      169
# 2157      Oklahoma      Harper        40       59
# 70          Alaska      Bethel         2       50
# 2377  South Dakota       Deuel        46       39
# 2556         Texas    Cherokee        48       73

# %%
#rename 'STATE_FIPS' columns to match df_mortality['STATE2KX']

df_state = df_state.rename(columns={"STATE_FIPS": "STATE2KX"})
df_state.sample(5)
# Out:
#     STATE2KX STUSAB STATE_NAME  STATENS
# 16        20     KS     Kansas   481813
# 45        50     VT    Vermont  1779802
# 46        51     VA   Virginia  1779803
# 11        15     HI     Hawaii  1779782
# 18        22     LA  Louisiana  1629543

# %%
#merge df_mortality and df_state based on 'STATE2KX' column. 

df_mortality = df_mortality.merge(df_county, on =['STATE2KX', 'CNTY2KX'], how = 'left')
df_mortality.sample(5)
# Out:
#           Tract ID  STATE2KX  CNTY2KX  TRACT2KX  e(0)  se(e(0))  \
# 48577  39151711111        39      151    711111  83.4    2.3067
# 8976    6073019303         6       73     19303  79.1    2.2700
# 9911    6085509304         6       85    509304  82.3    1.8239
# 7140    6059086502         6       59     86502  77.3    3.2876
# 31248  26125167400        26      125    167400  75.7    1.5229
#
#        Abridged life table flag STUSAB_x STATE_NAME_x  STATENS_x STUSAB_y  \
# 48577                         3       OH         Ohio    1085497       OH
# 8976                          3       CA   California    1779778       CA
# 9911                          2       CA   California    1779778       CA
# 7140                          2       CA   California    1779778       CA
# 31248                         3       MI     Michigan    1779789       MI
#
#       STATE_NAME_y  STATENS_y     State_x County Name_x     State_y  \
# ...

# %%
#verify merge produced correct values for STATE_NAME_x when STATE2KX = 45
# STATE2KX value matches correct STATE_NAME_x.  Example: STATE2KX = 45 -> STATE_NAME_x = South Carolina

df_mortality[df_mortality['CNTY2KX'] == 45].sample(5)
# Out:
#           Tract ID  STATE2KX  CNTY2KX  TRACT2KX  e(0)  se(e(0))  \
# 51978  42045406500        42       45    406500  66.9    2.7970
# 54527  45045003801        45       45      3801  79.9    0.8294
# 216     1045020500         1       45     20500  76.4    2.4299
# 39386  35045000607        35       45       607  79.3    1.8953
# 51940  42045403001        42       45    403001  79.2    1.5557
#
#        Abridged life table flag STUSAB_x    STATE_NAME_x  STATENS_x STUSAB_y  \
# 51978                         3       PA    Pennsylvania    1779798       PA
# 54527                         2       SC  South Carolina    1779799       SC
# 216                           3       AL         Alabama    1779775       AL
# 39386                         3       NM      New Mexico     897535       NM
# 51940                         3       PA    Pennsylvania    1779798       PA
#
#          STATE_NAME_y  STATENS_y         State_x County Name_x  \
# ...

# %%
#import employment data.  annual unemployment rate in each US County.

df_employment = pd.read_excel('/Users/marshallbanana/GitHub/Springboard2021/CAPSTONE 2 PROJECT FILES/Capstone 2 Project Data/Unemployment.xlsx', header = 4)
df_employment.head()
# Out:
#    FIPS_Code State           Area_name  Rural_urban_continuum_code_2013  \
# 0          0    US       United States                              NaN
# 1       1000    AL             Alabama                              NaN
# 2       1001    AL  Autauga County, AL                              2.0
# 3       1003    AL  Baldwin County, AL                              3.0
# 4       1005    AL  Barbour County, AL                              6.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2000  \
# 0                        NaN         NaN                142601576.0
# 1                        NaN         NaN                  2147173.0
# 2                        2.0         1.0                    21861.0
# 3                        2.0         1.0                    69979.0
# 4                        6.0         0.0                    11449.0
#
#    Employed_2000  Unemployed_2000  Unemployment_rate_2000  ...  \
# ...

# %%
df_employment.head()
# Out:
#    FIPS_Code State           Area_name  Rural_urban_continuum_code_2013  \
# 0          0    US       United States                              NaN
# 1       1000    AL             Alabama                              NaN
# 2       1001    AL  Autauga County, AL                              2.0
# 3       1003    AL  Baldwin County, AL                              3.0
# 4       1005    AL  Barbour County, AL                              6.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2000  \
# 0                        NaN         NaN                142601576.0
# 1                        NaN         NaN                  2147173.0
# 2                        2.0         1.0                    21861.0
# 3                        2.0         1.0                    69979.0
# 4                        6.0         0.0                    11449.0
#
#    Employed_2000  Unemployed_2000  Unemployment_rate_2000  ...  \
# ...

# %%
#import education data

df_education = pd.read_excel('/Users/marshallbanana/GitHub/Springboard2021/CAPSTONE 2 PROJECT FILES/Capstone 2 Project Data/Education.xls', header =4)

df_education = df_education.rename(columns={"FIPS Code": "FIPS_Code"})

df_education.head()
# Out:
#    FIPS_Code State       Area name  2003 Rural-urban Continuum Code  \
# 0          0    US   United States                              NaN
# 1       1000    AL         Alabama                              NaN
# 2       1001    AL  Autauga County                              2.0
# 3       1003    AL  Baldwin County                              4.0
# 4       1005    AL  Barbour County                              6.0
#
#    2003 Urban Influence Code  2013 Rural-urban Continuum Code  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        2.0                              2.0
# 3                        5.0                              3.0
# 4                        6.0                              6.0
#
#    2013 Urban Influence Code  Less than a high school diploma, 1970  \
# 0                        NaN                             52373312.0
# ...

# %%
# merge df_employment and df_education to df_emp_edu

df_emp_edu = df_employment.merge(df_education, on ='FIPS_Code', how = 'left')
df_emp_edu.sample(5)
# Out:
#       FIPS_Code State_x               Area_name  \
# 1346      27011      MN    Big Stone County, MN
# 3022      53037      WA     Kittitas County, WA
# 2162      39161      OH     Van Wert County, OH
# 2927      51117      VA  Mecklenburg County, VA
# 169        5101      AR       Newton County, AR
#
#       Rural_urban_continuum_code_2013  Urban_influence_code_2013  Metro_2013  \
# 1346                              9.0                       12.0         0.0
# 3022                              4.0                        3.0         0.0
# 2162                              6.0                        5.0         0.0
# 2927                              7.0                        9.0         0.0
# 169                               9.0                        8.0         0.0
#
#       Civilian_labor_force_2000  Employed_2000  Unemployed_2000  \
# 1346                     2767.0         2652.0            115.0
# 3022                    17511.0        16479.0           1032.0
# ...

# %%
# import poverty and income data. 
# description of column values:
#  'FIPStxt'  - State-county FIPS CODE
#  'POVALL2019' - Estimate of people of all ages in poverty 2019, 
#  'PCTPOVALL_2019' - Estimated percent of people of all ages in poverty 2019
# 'MEDHHINC_2019'  - Estimate of median household income

df_poverty = pd.read_excel('/Users/marshallbanana/GitHub/Springboard2021/CAPSTONE 2 PROJECT FILES/Capstone 2 Project Data/PovertyEstimates.xls', header =4)


df_poverty = df_poverty.rename(columns={"FIPStxt": "FIPS_Code"})
df_poverty.head()
# Out:
#    FIPS_Code Stabr       Area_name  Rural-urban_Continuum_Code_2003  \
# 0          0    US   United States                              NaN
# 1       1000    AL         Alabama                              NaN
# 2       1001    AL  Autauga County                              2.0
# 3       1003    AL  Baldwin County                              4.0
# 4       1005    AL  Barbour County                              6.0
#
#    Urban_Influence_Code_2003  Rural-urban_Continuum_Code_2013  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        2.0                              2.0
# 3                        5.0                              3.0
# 4                        6.0                              6.0
#
#    Urban_Influence_Code_2013  POVALL_2019  CI90LBALL_2019  CI90UBALL_2019  \
# 0                        NaN     39490096        39248096        39732096
# ...

# %%
# merge df_emp_edu and df_poverty to create df_emp_edu_pov


df_emp_edu_pov = df_emp_edu.merge(df_poverty, on ='FIPS_Code', how = 'left')
df_emp_edu_pov
# Out:
#       FIPS_Code State_x              Area_name_x  \
# 0             0      US            United States
# 1          1000      AL                  Alabama
# 2          1001      AL       Autauga County, AL
# 3          1003      AL       Baldwin County, AL
# 4          1005      AL       Barbour County, AL
# ...         ...     ...                      ...
# 3270      72145      PR  Vega Baja Municipio, PR
# 3271      72147      PR    Vieques Municipio, PR
# 3272      72149      PR   Villalba Municipio, PR
# 3273      72151      PR    Yabucoa Municipio, PR
# 3274      72153      PR      Yauco Municipio, PR
#
#       Rural_urban_continuum_code_2013  Urban_influence_code_2013  Metro_2013  \
# 0                                 NaN                        NaN         NaN
# 1                                 NaN                        NaN         NaN
# 2                                 2.0                        2.0         1.0
# ...

# %%
# extract county FIPS code and use for merging to df_mortality
# to extract county FIPS code, take last three digits of FIPS_Code valued

def last_three(x):
    numbers = list(str(x))
    return (numbers[-3] + numbers[-2] + numbers[-1])

last_three(36087011603)
# Out:
# '603'

# %%
# create 'fips_county' column in df_emp_edu_pov.  'fips_county' will be last three digits of 'FIPS_Code' value

codes=[]
for x in df_emp_edu_pov['FIPS_Code'].iteritems():
    #print(x[1])
    if len(str(x[1])) >= 2:
        codes.append(last_three(x[1]))
    else:
        codes.append(000)

len(codes), len(df_emp_edu_pov)
codes
# add county fips codes to df_emp_edu_pov dataframe

df_emp_edu_pov['FIPS county codes'] = codes

# verify correct FIPS county codes were produced and added to df_emp_edu_pov
df_emp_edu_pov[['FIPS_Code','FIPS county codes']]
# Out:
#       FIPS_Code FIPS county codes
# 0             0                 0
# 1          1000               000
# 2          1001               001
# 3          1003               003
# 4          1005               005
# ...         ...               ...
# 3270      72145               145
# 3271      72147               147
# 3272      72149               149
# 3273      72151               151
# 3274      72153               153
#
# [3275 rows x 2 columns]

# %%
# rename FIPS county codes and State_x columns in preparation for merging with df_mortality
df_emp_edu_pov = df_emp_edu_pov.rename(columns={"FIPS county codes": "CNTY2KX", "State_x": "STUSAB_x"})
df_emp_edu_pov
# Out:
#       FIPS_Code STUSAB_x              Area_name_x  \
# 0             0       US            United States
# 1          1000       AL                  Alabama
# 2          1001       AL       Autauga County, AL
# 3          1003       AL       Baldwin County, AL
# 4          1005       AL       Barbour County, AL
# ...         ...      ...                      ...
# 3270      72145       PR  Vega Baja Municipio, PR
# 3271      72147       PR    Vieques Municipio, PR
# 3272      72149       PR   Villalba Municipio, PR
# 3273      72151       PR    Yabucoa Municipio, PR
# 3274      72153       PR      Yauco Municipio, PR
#
#       Rural_urban_continuum_code_2013  Urban_influence_code_2013  Metro_2013  \
# 0                                 NaN                        NaN         NaN
# 1                                 NaN                        NaN         NaN
# 2                                 2.0                        2.0         1.0
# ...

# %%
df_mortality.sample(5)
# Out:
#           Tract ID  STATE2KX  CNTY2KX  TRACT2KX  e(0)  se(e(0))  \
# 43168  36087011603        36       87     11603  83.8    1.4183
# 13965  12053041103        12       53     41103  74.7    1.7402
# 22962  18103952600        18      103    952600  77.2    1.4171
# 28666  25009260302        25        9    260302  79.3    2.6625
# 44582  37063002022        37       63      2022  84.4    3.1388
#
#        Abridged life table flag STUSAB_x    STATE_NAME_x  STATENS_x STUSAB_y  \
# 43168                         3       NY        New York    1779796       NY
# 13965                         3       FL         Florida     294478       FL
# 22962                         3       IN         Indiana     448508       IN
# 28666                         3       MA   Massachusetts     606926       MA
# 44582                         3       NC  North Carolina    1027616       NC
#
#          STATE_NAME_y  STATENS_y         State_x County Name_x  \
# ...

# %%
#final merge

df_mortality = df_mortality.merge(df_emp_edu_pov, on = ['STUSAB_x', 'CNTY2KX'], how = 'left')

df_mortality.info(), df_mortality.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65662 entries, 0 to 65661
# Columns: 359 entries, Tract ID to CI90UB04P_2019_y
# dtypes: float64(332), int64(6), object(21)
# memory usage: 180.3+ MB
# (None, (65662, 359))

# %%
# Final Wrangled DataFrame, df_mortality, containing all data ready for exploratory data analysis

df_mortality.sample(5)
# Out:
#           Tract ID  STATE2KX CNTY2KX  TRACT2KX  e(0)  se(e(0))  \
# 7895    6067005205         6      67      5205  78.1    2.1789
# 50811  42003130300        42       3    130300  68.0    2.8102
# 36952  33011002200        33      11      2200  78.7    1.0719
# 35705  30087000100        30      87       100  88.3    3.0849
# 13029  12007000200        12       7       200  73.8    1.3418
#
#        Abridged life table flag STUSAB_x   STATE_NAME_x  STATENS_x  ...  \
# 7895                          2       CA     California    1779778  ...
# 50811                         3       PA   Pennsylvania    1779798  ...
# 36952                         2       NH  New Hampshire    1779794  ...
# 35705                         3       MT        Montana     767982  ...
# 13029                         3       FL        Florida     294478  ...
#
#       CI90UB517P_2019_y MEDHHINC_2019_y  CI90LBINC_2019_y CI90UBINC_2019_y  \
# ...
